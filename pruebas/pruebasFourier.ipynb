# %%
import numpy as nepe
import matplotlib.pyplot as plt
x=nepe.linspace(0,1,100)
f_x=nepe.sin(2*nepe.pi*x)
FT_f_x=nepe.fft.fft(f_x)
shifted_FT=nepe.fft.fftshift(FT_f_x)
magnitude=nepe.abs(shifted_FT)**2
plt.plot(x,f_x)
plt.show()
plt.plot(magnitude)
plt.show()
